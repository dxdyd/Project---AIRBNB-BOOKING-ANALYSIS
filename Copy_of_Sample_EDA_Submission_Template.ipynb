# %% [markdown]
# <a href="https://colab.research.google.com/github/dxdyd/Project---AIRBNB-BOOKING-ANALYSIS/blob/main/Copy_of_Sample_EDA_Submission_Template.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name**    - AIR BNB BOOKING ANALYSIS

# %% [markdown]
# ##### **Project Type**    - EDA
# ##### **Contribution**    - Individual
# ##### **Team Member 1 -** Aditya Sarma

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# Since 2008, guest and host have used Airbnb to expand on traveling possibilities and present a more unique ,personalize way of experiencing the world. Today, Airbnb became one of a kind service that is used and recognized by the whole world. Data analysis on a million of listings provided through Airbnb is a crucial factor for the company. These million of listings generate a lot of data - data that can be analysed and used for security, business decisions, understanding of customer's and provider's (hosts) behaviour and performance on the platform, guiding marketing, initiatives, implementation of innovative, additional service and much more.
#
# This dataset has around 49,000 observations in it with 16 columns and it is a mix of categorical and numeric values.
#
# This project is to aims to analyze the hotel booking data to gain insights and make data-driven decisions for improving the hotel's operations and customer experience. By examining various aspects of data
#
# Objectives:
# 1. Understanding booking patterns
# 2. Customer segmentation
# 3. Revenue analysis
# 4. Demand forecasting
# 5. Customer feedback analysis
# 6. Competitor analysis

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# Provide your GitHub Link here.

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# **Write Problem Statement Here.**

# %% [markdown]
# Explore and analyze the data to discover the key understandings

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# 1) What can we learn about different hosts and areas?
#
# 2) What can we learn from predictions? (ex: locations, prices, reviews, etc)
#
# 3) Which hosts are the busiest and why?
#
# 4) Is there any noticeable difference of traffic among different areas and what could be the reason for it?

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from skimage.io import imread
import matplotlib.pyplot as plt
# %matplotlib inline
from collections import Counter

# %%
url = 'https://drive.google.com/file/d/1ioU5r9KEYSfwgfUi22SclVkx4l1a_8ou/view?usp=sharing'
url = 'https://drive.google.com/uc?id=' + url.split('/')[-2]
df = pd.read_csv(url)
df
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %% [markdown]
# ### Dataset Loading

# %%
df.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %% [markdown]
# ### Dataset First View

# %%
df.describe()
# Out:
#                  id       host_id      latitude     longitude         price  \
# count  4.889500e+04  4.889500e+04  48895.000000  48895.000000  48895.000000
# mean   1.901714e+07  6.762001e+07     40.728949    -73.952170    152.720687
# std    1.098311e+07  7.861097e+07      0.054530      0.046157    240.154170
# min    2.539000e+03  2.438000e+03     40.499790    -74.244420      0.000000
# 25%    9.471945e+06  7.822033e+06     40.690100    -73.983070     69.000000
# 50%    1.967728e+07  3.079382e+07     40.723070    -73.955680    106.000000
# 75%    2.915218e+07  1.074344e+08     40.763115    -73.936275    175.000000
# max    3.648724e+07  2.743213e+08     40.913060    -73.712990  10000.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count    48895.000000       48895.000000       38843.000000
# mean         7.029962          23.274466           1.373221
# std         20.510550          44.550582           1.680442
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
df.shape
# Out:
# (48895, 16)

# %% [markdown]
# ### Dataset Information

# %%
df.info

# %% [markdown]
# #### Duplicate Values

# %%
duplicate_values = df[df.duplicated()]
print(duplicate_values)
# Out:
# Empty DataFrame
# Columns: [id, name, host_id, host_name, neighbourhood_group, neighbourhood, latitude, longitude, room_type, price, minimum_nights, number_of_reviews, last_review, reviews_per_month, calculated_host_listings_count, availability_365]
# Index: []

# %% [markdown]
# #### Missing Values/Null Values

# %%
newdf = df.copy()
df.reviews_per_month.fillna(value = 0, inplace = True)
df['last_review'] = pd.to_datetime(df['last_review'], format = '%Y-%m-%d')
df.last_review = df['last_review'].dt.year.astype('object')
df.last_review.fillna(value = 'Never', inplace = True)

# %%
df.isnull().sum()
# Out:
# id                                 0
# name                              16
# host_id                            0
# host_name                         21
# neighbourhood_group                0
# neighbourhood                      0
# latitude                           0
# longitude                          0
# room_type                          0
# price                              0
# minimum_nights                     0
# number_of_reviews                  0
# last_review                        0
# reviews_per_month                  0
# calculated_host_listings_count     0
# availability_365                   0
# dtype: int64

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# OBSERVATIONS:
# *   The dataset contain a total of 16 columns.
# *   There are 48895 observations in total.
# *   Columns like name,host_name,last_review,reviews_per_month have missing values. name and host_name column is not important as it does not convey any meaningful data. So those columns can be dropped.
# *   last_review and reviews_per_month have the same number of NaN values which means certain properties were not rated at all hence last_review has no date and reviews_per_month has no data.
# *   On average, people stay in a room for 7 days.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
columns = df.columns
print("Dataset Columns:")
print(columns)
# Out:
# Dataset Columns:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365'],
#       dtype='object')

# %%
# Dataset Describe
description = df.describe()
print("\nDataset Describe:")
print(description)
# Out:
# Dataset Describe:
#                  id       host_id      latitude     longitude         price  \
# count  4.889500e+04  4.889500e+04  48895.000000  48895.000000  48895.000000
# mean   1.901714e+07  6.762001e+07     40.728949    -73.952170    152.720687
# std    1.098311e+07  7.861097e+07      0.054530      0.046157    240.154170
# min    2.539000e+03  2.438000e+03     40.499790    -74.244420      0.000000
# 25%    9.471945e+06  7.822033e+06     40.690100    -73.983070     69.000000
# 50%    1.967728e+07  3.079382e+07     40.723070    -73.955680    106.000000
# 75%    2.915218e+07  1.074344e+08     40.763115    -73.936275    175.000000
# max    3.648724e+07  2.743213e+08     40.913060    -73.712990  10000.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count    48895.000000       48895.000000       38843.000000
# mean         7.029962          23.274466           1.373221
# std         20.510550          44.550582           1.680442
# ...

# %% [markdown]
# ### Variables Description

# %% [markdown]
# 1) The minimum 'price'  is 0, which is not possible.
#
# 2) The Maximum 'minimum_nights' is 1250 which is also highly unlikely.

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
unique_values = {}
for column in df.columns:
    unique_values[column] = df[column].unique()

for column, values in unique_values.items():
    print(f"Unique values for {column}:")
    print(values)
    print()

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %% [markdown]
# Looks there are some property listed with 0 listed price!

# %%
len(df[df['price']==0]) #so 11 property/listings have 0 price listed.
# Out:
# 11

# %%
# Write your code to make your dataset analysis ready.
# A function for price_correction
def price_correction(x):
    if x==0:
        return 100
    else:
        return x

# %%
df[df['price']==0]
#Rows which have 'price'=0

# %%
# Using the price_correction function to change the 'price'
df['price']=df['price'].apply(price_correction)
# 'price' has no value equal to zero
df[df['price']==0]
#Changing values of 'minimum_nights' to 365 which are greater than 365
df['minimum_nights']=df['minimum_nights'].apply(lambda x: 365 if x>365 else x)
df.describe()
# Out:
#                  id       host_id      latitude     longitude         price  \
# count  4.889500e+04  4.889500e+04  48895.000000  48895.000000  48895.000000
# mean   1.901714e+07  6.762001e+07     40.728949    -73.952170    152.743184
# std    1.098311e+07  7.861097e+07      0.054530      0.046157    240.144546
# min    2.539000e+03  2.438000e+03     40.499790    -74.244420     10.000000
# 25%    9.471945e+06  7.822033e+06     40.690100    -73.983070     69.000000
# 50%    1.967728e+07  3.079382e+07     40.723070    -73.955680    106.000000
# 75%    2.915218e+07  1.074344e+08     40.763115    -73.936275    175.000000
# max    3.648724e+07  2.743213e+08     40.913060    -73.712990  10000.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count    48895.000000       48895.000000       38843.000000
# mean         6.942980          23.274466           1.373221
# std         17.530294          44.550582           1.680442
# ...

# %%
max_hostid=df['host_id'].value_counts().head(10)
max_hostid
#Considering 10 highest host_id listings.The maximum host_id listing is 327.
# Out:
# 219517861    327
# 107434423    232
# 30283594     121
# 137358866    103
# 16098958      96
# 12243051      96
# 61391963      91
# 22541573      87
# 200380610     65
# 7503643       52
# Name: host_id, dtype: int64

# %%
#creating a dataframe with max_hostid data
df_hostid=pd.DataFrame(data=max_hostid)
df_hostid.reset_index(inplace=True)
df_hostid.rename(columns={'index':'Host_ID', 'host_id':'Listings_Count'}, inplace=True)
df_hostid

# %%
df['host_name'].nunique() #unique hosts

# %%
df['name'].value_counts()
#an interesting observation, looks like few listings have no particular host name as below observation!
#also few listings/property with same names has different hosts in different areas/neighbourhoods of a neighbourhood_group

# %%
df[df['name']==df['host_name']] #looks there are few listings where the property name and the host have same names!
#we can remove duplicates later in our analysis!

# %%
df[df['name']=='New york Multi-unit building'].head(4) #so on this viewpoint name also comes under categorical var!
#same property but hosted by different Airbnb hosts with different room_types & varied price ranges

# %%
df.loc[(df['neighbourhood_group']=='Manhattan') & (df['host_name']=='Natasha')] #experiment
#Same hosts have hosted for different properties in same neighbourhood groups!

# %% [markdown]
# if a person trying to book a listing for stay/rent he/she will look into these following factors while booking:
# name,host_name,neighbourhood_group,neighbourhood,room_type,price,minimum_nights,number_of_reviews
# these are the important ones in our analysis.

# %%
df['host_name'].value_counts()[:5] #5 hosts with most listings counts in entire NYC
# Out:
# Michael         417
# David           403
# Sonder (NYC)    327
# John            294
# Alex            279
# Name: host_name, dtype: int64

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# So, far i was trying to correct the 'prices',rows which have NaN value.
#
#
#  I was trying to understand the two variables: name and host_name & its relationship with neighbourhood_group and neighbourhood.(only from the values present inside)
#
# Found out that: A host can have multiple properties in a neighbourhood group with different host-ids but a host with a particular property/listing in a particular neighbourhood of a neighbourhood group have a same host-id(not mandatory as there are exceptions where few hosts have diferrent id's for each listing/property in a neighbourhood)
#
# Also the data so far tells, there might be cases where a particular host has co-hosted someone else's property/listing in a neighbourhood on Airbnb.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1

# %%
# Chart - 1 visualization code
plt.rcParams['figure.figsize'] = (8, 5)
ax= sns.countplot(y='room_type',hue='neighbourhood_group',data=df,palette='bright')

total = len(df['room_type'])
for p in ax.patches:
        percentage = '{:.1f}%'.format(100 * p.get_width()/total)
        x = p.get_x() + p.get_width() + 0.02
        y = p.get_y() + p.get_height()/2
        ax.annotate(percentage, (x, y))

plt.title('count of each room types in entire NYC')
plt.xlabel('Rooms')
plt.xticks(rotation=90)
plt.ylabel('Room Counts')

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The specific chart used in the code snippet is a countplot with stacked bars representing the count of each room type, grouped by neighborhood. This chart is suitable when we want to visualize the distribution of different room types across different neighborhoods.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Manhattan has more listed properties with Entire home/apt around 27% of total listed properties followed by Brooklyn with around 19.6%.
#
# Private rooms are more in Brooklyn as in 20.7% of the total listed properties followed by Manhattan with 16.3% of them. While 6.9% of private rooms are from Queens.
#
# Very few of the total listed have shared rooms listed on Airbnb where there's negligible or almost very rare shared rooms in Staten Island and Bronx.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The gained insights can potentially help create a positive business impact. For example:
#
# Identifying the most popular room types can help businesses in the hospitality industry tailor their offerings and marketing strategies to meet customer preferences.
#
# Understanding the distribution of room types across neighborhoods can guide businesses in determining the appropriate pricing and availability of different types of accommodations in specific areas.
#
# Regarding negative growth, it depends on the specific insights gained from the chart and how they are interpreted. Negative growth may occur if the data reveals a significant decline in the popularity of certain room types or if there are imbalances in the distribution of room types across neighborhoods, indicating potential issues with demand or market saturation. However, without specific insights from the chart, it's not possible to determine if there are any negative growth factors present in your dataset.

# %% [markdown]
# #### Chart - 2

# %%
# Chart - 2 visualization code
plt.figure(figsize=(10, 6))
sns.countplot(x='neighbourhood_group', data=df)
plt.title('Neighbourhood Group')
plt.xlabel('Neighbourhood Group')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The specific chart used in the code snippet is a countplot with bars representing the count of each neighborhood group. This chart is suitable when we want to visualize the distribution of data across different categories, in this case, the neighborhood groups.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The insights that can be obtained from the chart include:
#
# The count of listings in each neighborhood group, providing an understanding of the distribution and popularity of listings across different areas.
#
# Mahattan has highest 'count' compare to others, followed by Brooklyn
# and Staten Island has the least count.
#
# Comparisons between neighborhood groups in terms of the number of listings, which can help identify areas with high or low market activity.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The gained insights can potentially help create a positive business impact. For example:
#
# Understanding the popularity of different neighborhood groups can guide businesses in making strategic decisions, such as focusing marketing efforts on areas with high demand or expanding into emerging neighborhoods.
#
# Identifying areas with low market activity can present opportunities for businesses to target those areas and potentially gain a competitive advantage.
#
# As for negative growth, it would depend on the specific insights gained from the chart and how they are interpreted. Negative growth could occur if there are significant imbalances in the distribution of listings across neighborhood groups, indicating that certain areas are losing popularity or facing challenges. However, without specific insights from the chart, it's not possible to determine if there are any negative growth factors present in your dataset.

# %% [markdown]
# #### Chart - 3

# %%
# Chart - 3 visualization code
#distribution of listings availability at NYC!
sns.distplot(df['availability_365'])
# Out:
# <ipython-input-3-1b0158b070dc>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['availability_365'])
# <Axes: xlabel='availability_365', ylabel='Density'>

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The specific chart used in the code snippet is a distribution plot (distplot) that visualizes the distribution of listings' availability in NYC. This chart was likely chosen to understand the spread and frequency of availability values within the dataset.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The insights that can be obtained from the chart include:
#
# The shape of the distribution: The plot can show whether the availability values are concentrated around a particular range or if they are more evenly distributed.
#
# Central tendency: The peak or center of the distribution can provide insights into the most common availability value.
#
# Spread: The width and range of the distribution can indicate the variability in availability values.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The gained insights can potentially help create a positive business impact. For example:
#
# Understanding the distribution of listings' availability can help businesses in the hospitality industry optimize their pricing and occupancy strategies. They can identify peak availability periods to adjust prices accordingly.
#
# It can also assist in planning resource allocation, staffing, and maintenance schedules based on demand patterns.
#
# Negative growth insights might arise if the distribution plot reveals undesirable patterns, such as:
#
# High concentration of availability values at low or high extremes: This might suggest limited availability or a lack of demand during certain periods, potentially impacting revenue.
#
# A skewed distribution: If the availability values are heavily skewed towards one end of the spectrum, it may indicate imbalances in demand or supply, which can negatively impact business planning and profitability.
#
# To determine the specific positive or negative impacts, it is important to analyze the insights gained from the distribution plot in the context of the business goals and strategies.

# %% [markdown]
# #### Chart - 4

# %%
# Chart - 4 visualization code
plt.scatter(df['id'], df['price'])
plt.xlabel('Listing ID')
plt.ylabel('Price')
plt.title('Price vs. Listing ID')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The specific chart used in the code snippet is a scatter plot with the listing ID on the x-axis and the price on the y-axis. This chart is suitable when we want to visualize the relationship or distribution between two continuous variables, such as price and listing ID.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The insights that can be obtained from the chart include:
#
# The general pattern or trend between the listing ID and the price. This can help identify any correlations or relationships between the variables.
#
# The range and variability of prices across different listing IDs.
#
# Any potential outliers or unusual price points that may require further investigation.
#
# As we can see that maximum density are in the 'price' range of 0 - 1500, from this we can say that customers prefer less price hotels (Airbnb) than expensive once.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The gained insights can potentially help create a positive business impact. For example:
#
# Understanding the relationship between listing ID and price can help businesses determine if there is any pricing pattern or trend that can be utilized for pricing strategies.
#
# Identifying outliers or unusual price points can help businesses identify pricing errors, anomalies, or opportunities for optimization.
#
# Regarding negative growth, it's not directly applicable in the context of a scatter plot with price and listing ID. Negative growth is typically associated with time-series data or comparisons between different periods. In this case, the scatter plot shows the relationship between two continuous variables and doesn't provide direct information about growth or decline. However, if specific patterns or outliers in the scatter plot indicate problematic pricing or market conditions, they could potentially lead to negative growth if not addressed or managed appropriately.

# %% [markdown]
# #### Chart - 5

# %%
# Chart - 5 visualization code
plt.plot(df['id'], df['price'])
plt.xlabel('Listing ID')
plt.ylabel('Price')
plt.title('Price Trend')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The specific chart used in the code snippet is a line plot that represents the price trend of listings based on their ID numbers. This type of chart is commonly used to visualize the relationship between two variables over a continuous axis, in this case, the listing ID and the corresponding price.
#
# Although, I have already shown the same graph in terms of scatterplot but in line graph we can distinguish the specific line corresponding to the 'Listing_Id'

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The insights that can be obtained from the chart include:
#
# The overall trend in prices based on the order of listing IDs.
#
# Patterns or fluctuations in prices over time.
#
# Potential outliers or anomalies in the price data.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The gained insights can potentially help create a positive business impact. For example:
#
# Identifying price trends can assist businesses in understanding the market dynamics and making informed pricing decisions.
#
# Recognizing patterns or fluctuations in prices can help businesses adjust their pricing strategies based on seasonal or market changes.
#
# Detecting outliers or anomalies in prices can indicate potential pricing errors or opportunities for optimization.
#
# Regarding negative growth, it depends on the specific insights gained from the chart and how they are interpreted. Negative growth may occur if the price trend shows a consistent decline over time or if there are significant outliers indicating excessively high or low prices. However, without specific insights from the chart, it's not possible to determine if there are any negative growth factors present in your dataset.

# %% [markdown]
# #### Chart - 6

# %%
# Chart - 6 visualization code
room_type_counts = df['room_type'].value_counts()
plt.pie(room_type_counts, labels=room_type_counts.index, autopct='%1.1f%%')
plt.title('Room Type Distribution')
plt.axis('equal')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The specific chart used in the code snippet is a pie chart. This chart is commonly used to represent the distribution of categorical data as proportions or percentages of a whole. It is suitable when you want to visualize the proportion of each category within a variable.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The insights that can be obtained from the pie chart include:
#
# The distribution of room types as a percentage of the total.
#
# The relative popularity of different room types.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The gained insights can potentially help create a positive business impact. For example:
#
# Understanding the distribution of room types can inform businesses in the hospitality industry about the most popular room types among their target audience, which can help in making informed decisions about resource allocation, marketing strategies, and service offerings.
#
# By identifying the least popular room types, businesses can focus on improving or modifying those offerings to increase their attractiveness to customers.
#
# Regarding negative growth, it depends on the specific insights gained from the chart. Negative growth may occur if the pie chart reveals a decline in the popularity of certain room types over time or if there is an imbalanced distribution where a particular room type is significantly less popular compared to others. However, without specific insights from the chart, it's not possible to determine if there are any negative growth factors present in your dataset.

# %% [markdown]
# #### Chart - 7

# %%
# Chart - 7 visualization code
plt.boxplot(df['price'])
plt.ylabel('Price')
plt.title('Box Plot: Price Distribution')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I, chose box plot so that we can see the density of price in a single line which will help us to distinguish price distribution

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# As we can see that maximum customer preferred 'price' till 4000 and every least amount of customer went for high pricing and luxurious hotel(Airbnb).
#
# We can also say that with cheap price, hotel can make profits and satisfy the customer with needs

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The gained insights can potentially help create a positive business impact. For example:
#
# Identifying the most popular room types can help businesses in the hospitality industry tailor their offerings and marketing strategies to meet customer preferences.
#
# Understanding the distribution of room types across neighborhoods can guide businesses in determining the appropriate pricing and availability of different types of accommodations in specific areas.
#
# Regarding negative growth, it depends on the specific insights gained from the chart and how they are interpreted. Negative growth may occur if the data reveals a significant decline in the popularity of certain room types or if there are imbalances in the distribution of room types across neighborhoods, indicating potential issues with demand or market saturation. However, without specific insights from the chart, it's not possible to determine if there are any negative growth factors present in your dataset.

# %% [markdown]
# #### Chart - 8

# %%
# Chart - 8 visualization code
neighbourhoods = df.groupby('neighbourhood')['availability_365'].mean().nlargest(10)

plt.fill_between(neighbourhoods.index, neighbourhoods.values)
plt.xlabel('Neighbourhood')
plt.ylabel('Average Availability (365 days)')
plt.title('Area Chart: Top 10 Neighbourhoods by Availability')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# With the help of area chart we can clearly see the availability of the rooms through all years with different neighbourhoods

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From these chart I can say that Fort Wadsworth and Co-op City has the room available throughout all the years.
#
# and Spuyten Duyvil has availablity of rooms less than 300 days

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The gained insights can potentially help create a positive business impact. For example:
# The identified top 10 neighborhoods with high availability can be targeted for real estate investment or property development projects.
#
# The information can guide businesses in the hospitality industry, such as hotels or short-term rental platforms, to focus their marketing efforts on these neighborhoods with high availability.
#
# It can assist in making informed decisions regarding property pricing, as neighborhoods with high availability may require competitive pricing strategies to attract tenants or guests.
#
# Regarding negative growth, it is not explicitly evident from the chart whether there are any insights leading to negative growth. The chart only displays the average availability of properties, and without further context or comparison to other variables or time periods, it is difficult to determine negative growth trends. Negative growth insights would require additional analysis of other relevant factors, such as property demand, rental rates, or occupancy rates, to provide a comprehensive understanding of the market dynamics.

# %% [markdown]
# #### Chart - 9

# %%
# Chart - 9 visualization code
reviews_per_month = df.groupby('neighbourhood_group')['reviews_per_month'].mean()
plt.plot(reviews_per_month.index, reviews_per_month.values)
plt.xlabel('Neighbourhood Group')
plt.ylabel('Average Reviews per Month')
plt.title('Line Chart: Average Reviews per Month by Neighbourhood Group')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The specific chart chosen is a line chart because it is suitable for visualizing the trend or changes in a continuous variable (average reviews per month) across different categories (neighbourhood groups). It allows for easy comparison between the neighbourhood groups and facilitates the identification of any patterns or variations in the data.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# As we can see:
# Queens has the highest reviews given by the customers, followed by Staten Island and Bronx
#
# Least amount of reviews given by the people in the neighbourhoods are Brooklyn and Manhattan

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The gained insights can potentially help create a positive business impact. For instance:
#
# The chart can assist in identifying the neighbourhood groups with higher average reviews per month. This information can be used to focus marketing and promotional efforts in those areas to attract more guests and increase bookings.
#
# It can highlight any underperforming neighbourhood groups with lower average reviews per month, allowing businesses to investigate potential issues and implement strategies to improve guest satisfaction and increase reviews.
#
# By understanding the differences in average reviews per month across neighbourhood groups, businesses can tailor their services, amenities, and pricing strategies to meet the specific preferences and expectations of guests in each area.
#
# As for negative growth, it depends on the specific insights derived from the chart. If there are neighbourhood groups with consistently low average reviews per month, it could indicate issues that need to be addressed to prevent negative growth. For example:
#
# If a particular neighbourhood group has a declining trend in average reviews per month over time, it may suggest a decrease in guest satisfaction or a decline in the attractiveness of the area. This insight can prompt businesses to investigate and address the underlying causes to prevent further negative growth.
#
# Similarly, if there are significant variations or outliers in average reviews per month for certain neighbourhood groups, it may indicate inconsistent guest experiences or issues affecting guest satisfaction. Addressing these issues promptly can help avoid negative growth and maintain a positive reputation.
#
# Overall, the gained insights from the chart can be used strategically to optimize business operations, improve guest satisfaction, and drive positive growth.

# %% [markdown]
# #### Chart - 10

# %%
# Chart - 10 visualization code
#trying to find where the coordinates belong from the latitude and longitude
sns.set(rc={"figure.figsize": (10, 8)})
ax= sns.scatterplot(data=df, x="longitude", y="latitude",hue='neighbourhood_group',palette='bright')
ax.set_title('Location Co-ordinates')
# Out:
# Text(0.5, 1.0, 'Location Co-ordinates')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I picked a scatterplot chart because it allows us to visualize the relationship between latitude and longitude coordinates on a two-dimensional plane. Scatterplots are commonly used to display the distribution and relationships between two continuous variables, which in this case are latitude and longitude.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From the chart, we can observe the distribution of data points across different latitude and longitude coordinates. The hue encoding, using the 'neighbourhood_group' column, adds an additional dimension to the plot by differentiating data points belonging to different neighborhood groups. This allows us to identify clusters or patterns based on the neighborhood groups.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The gained insights can potentially help in creating a positive business impact. By analyzing the distribution of data points across different neighborhoods, businesses can identify areas with high concentration or density of customers. This information can be used for various purposes such as targeted marketing campaigns, optimizing store locations, identifying popular areas for real estate investments, and more.
#
# As for negative growth, it depends on the specific insights derived from the chart and the business context. If there are areas with a significantly lower density or concentration of customers, it might indicate less potential for business growth in those regions. However, this does not necessarily imply negative growth, but rather a potential area for lesser business opportunities compared to other regions. Decisions related to negative growth or potential risks should be based on a more comprehensive analysis, considering various factors beyond just the geographic distribution of data points.

# %% [markdown]
# #### Chart - 11

# %%
# Chart - 11 visualization code
sns.set(rc={"figure.figsize": (10, 8)})
ax= sns.scatterplot(x=df.longitude, y=df.latitude,hue=df.room_type,palette='muted')
ax.set_title('Distribution of type of rooms across NYC')
# Out:
# Text(0.5, 1.0, 'Distribution of type of rooms across NYC')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The specific chart chosen is a scatter plot with points colored by the room type (hue=df.room_type). This choice was made because the scatter plot is suitable for visualizing the distribution of two continuous variables (longitude and latitude) and the additional dimension of room type is represented by different colors.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The insights found from the chart include:
#
# The distribution of different room types across NYC can be observed.
# The concentration of different room types in specific areas can be identified.
# Patterns or clusters of room types in certain geographical regions may emerge.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The gained insights can potentially help in creating a positive business impact. Here's why:
#
# Targeted marketing: By understanding the distribution of room types across NYC, businesses can target their marketing efforts to specific areas. For example, if certain room types are more popular in certain neighborhoods, businesses can focus their promotional activities and tailor their offerings to match the preferences of customers in those areas.
#
# Strategic investment: Insights from the chart can inform decisions regarding the allocation of resources and investments. If there are areas with a high concentration of a particular room type and a growing demand, businesses can consider investing in expanding their offerings or establishing new properties in those areas.
#
# Customer segmentation: The chart can help identify different clusters or patterns of room types, which can be useful for customer segmentation. By understanding the preferences of different customer segments, businesses can create targeted marketing campaigns and personalized experiences for their customers.
#
# Negative growth insights might arise if certain room types are consistently underperforming or have a declining demand in specific areas. For example, if the scatter plot reveals a significant lack of demand or low popularity for a particular room type in multiple regions, it may indicate that offering that room type might not be profitable or might require adjustments to attract customers. However, without specific data or further analysis, it is challenging to make a definitive judgment on negative growth. The insights gained from the chart should be further analyzed and validated using additional data and business context to assess their potential positive or negative impact on a specific business.

# %% [markdown]
# #### Chart - 12

# %%
# Chart - 12 visualization code
lat_long = df.plot(
    kind='scatter',
    x='longitude',
    y='latitude',
    label='prices?',
    c='price',
    cmap='coolwarm',
    colorbar=True,
    alpha=0.4,
    figsize=(10, 8)
)
lat_long.legend()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A scatter plot is commonly used to display the relationship between two numerical variables. In this case, the scatter plot is chosen to visualize the relationship between longitude and latitude, with the color representing the price. This choice allows for the exploration of any spatial patterns or clusters in the data.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Insights from the Chart:
#
# To gain insights from the chart, you would need to analyze the patterns and relationships between the variables. Here are a few possible insights you could derive from the scatter plot:
#
# Spatial Distribution: The scatter plot can show the geographical distribution of prices. You can identify if certain areas have higher or lower prices, or if there are any clusters or patterns based on the color variation.
#
# Correlation: The scatter plot can help assess the relationship between price and location. If there is a noticeable trend, such as prices increasing or decreasing as you move in a specific direction, it suggests a potential correlation between price and longitude or latitude.
#
# Outliers: Scatter plots can help identify any outliers in the data, where specific locations have unusually high or low prices compared to their geographical neighbors.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Business Impact:
#
# The potential business impact depends on the specific insights gained from the scatter plot and the context of your business. If the insights reveal useful patterns or correlations, they can inform decision-making processes and strategies. For example:
# Pricing Strategy: If there are clear spatial patterns in price distribution, you can adjust your pricing strategy accordingly. Areas with higher demand or higher prices could be targeted differently than areas with lower prices.
#
# Market Segmentation: Insights from the scatter plot might suggest the presence of distinct market segments based on geographical location. This information can help tailor marketing and advertising efforts to specific regions.
#
# Investment Decisions: Understanding the relationship between price and location can guide investment decisions, such as where to open new branches, expand operations, or focus marketing campaigns.
#
# However, without specific insights from the scatter plot, it is not possible to determine if there are negative impacts. Negative growth or potential risks can arise if the analysis reveals unfavorable patterns, such as areas with consistently declining prices or a lack of demand in certain locations. Assessing the potential impact requires a deeper understanding of the data and business context.

# %% [markdown]
# #### Chart - 13

# %%
# Chart - 13 visualization code
f, ax = plt.subplots(figsize=(10, 8))
ax=sns.scatterplot(data=df,x='longitude', y='latitude', hue="availability_365",palette='coolwarm',size='availability_365',
    sizes=(20,300))

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The specific chart chosen appears to be a scatter plot created using the Seaborn library. The scatter plot is suitable for visualizing the relationship between latitude and longitude, with color encoding based on the "availability_365" variable. The size of the markers also represents the "availability_365" values.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The insights that can be obtained from the chart would depend on the data in the "df" DataFrame and the specific variables used. However, some potential insights could include:
#
# Clustering of high availability areas: Areas with a high density of markers or larger markers may indicate locations with higher availability throughout the year.
#
# Geographic distribution: The scatter plot can provide insights into the geographic distribution of listings, revealing patterns or concentrations in certain regions.
#
# Potential correlations: The color encoding and size representation can help identify any potential relationships between availability and geographic coordinates.
#
# Also, looks Bronx & Staten Island has listings which are mostly available throughout the year, might be the case as they are not much costlier as compared to other boroughs as in Manhanttan, Brooklyn & Queens.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The gained insights can potentially have a positive business impact. For example:
#
# Understanding high availability areas: Identifying regions with consistently high availability throughout the year can help businesses focus their marketing efforts and target customers who prefer more available options.
#
# Geographical targeting: By analyzing the geographic distribution of listings, businesses can identify popular areas and allocate resources accordingly, such as expanding operations or optimizing advertising campaigns in those regions.
#
# Regarding negative growth, it is difficult to make specific judgments without examining the data and the insights gained. Negative growth could arise if the analysis reveals areas with consistently low availability or areas where demand is declining. However, without specific information, it is not possible to justify negative growth impacts.
#
# It's important to note that the actual insights and business impact would depend on the specific data, the context, and the objectives of the analysis. Further analysis and domain knowledge would be required to draw more accurate conclusions and determine the potential positive or negative impact on the business.

# %% [markdown]
# #### Chart - 14 - Correlation Heatmap

# %%
# Correlation Heatmap visualization code
correlation_matrix = df.corr()
sns.heatmap(correlation_matrix, annot=True)
plt.title('Correlation Heatmap')
plt.show()
# Out:
# <ipython-input-15-d0a893e52a11>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = df.corr()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The specific chart used in the code snippet is a correlation heatmap. This chart is used to visualize the correlations between different variables in a dataset. It is suitable when we want to explore the relationships and dependencies among variables

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The insights that can be obtained from the correlation heatmap include:
#
# Clearly from the heatmap we can see the correlation between different features that can affect a airbnb listing.
#
# Guess what? There's correlation among host_id to reveiws_per_month & availability_365. Also there's noticiable correlation between min_nights to no_of_listings_count & availability_365. Price also shows some correlation with availability_365 & host_listings_count.
#
# no_of_reviews and reviews_per_month gives almost the same information. so we can carry out analysis with any of the two variable. Also, no_of_reviews is correlated to availability_365!

# %% [markdown]
# #### Chart - 15 - Pair Plot

# %%
# Pair Plot visualization code
sns.pairplot(df[['price', 'minimum_nights', 'number_of_reviews', 'reviews_per_month']])
plt.title('Pair Plot')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The specific chart used in the code snippet is a pair plot. This chart is used to visualize the relationships and patterns between multiple variables in a dataset. It creates a matrix of scatterplots where each variable is plotted against every other variable.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The insights that can be obtained from the pair plot include:
#
# Identifying correlations: The pair plot can reveal any positive or negative correlations between variables, such as the relationship between price and minimum nights, price and number of reviews, or number of reviews and reviews per month. These correlations can inform pricing strategies, promotional campaigns, or operational decisions.
#
# Outlier detection: The pair plot can help identify outliers, which are data points that deviate significantly from the overall pattern. Outliers in variables like price or number of reviews can indicate potential issues that may need attention or adjustment.

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# 1) What can we learn about different hosts and areas?

# %%
host_areas = df.groupby(['host_name','neighbourhood_group'])['calculated_host_listings_count'].count().reset_index()
host_areas.sort_values(by='calculated_host_listings_count', ascending = False).head(5)
# Out:
#           host_name neighbourhood_group  calculated_host_listings_count
# 13217  Sonder (NYC)           Manhattan                             327
# 1834     Blueground           Manhattan                             230
# 9742        Michael           Manhattan                             212
# 3250          David           Manhattan                             202
# 9741        Michael            Brooklyn                             159

# %% [markdown]
# As we can see most number of listings are from Manhattan created Sondar (NYC), Blueground, Michael, David

# %% [markdown]
# 2) What can we learn from predictions? (ex: locations, prices, reviews, etc)

# %%
areas_reviews = df.groupby(['name', 'neighbourhood_group', 'price', 'minimum_nights'])['number_of_reviews'].count().reset_index()
price_reviews1 = areas_reviews.sort_values(by='price',ascending = False).head(100)
price_reviews1
# Out:
#                                                     name neighbourhood_group  \
# 20219                Furnished room in Astoria apartment              Queens
# 27223    Luxury 1 bedroom apt. -stunning Manhattan views            Brooklyn
# 1112                                 1-BR Lincoln Center           Manhattan
# 2224   2br - The Heart of NYC: Manhattans Lower East ...           Manhattan
# 36152                Quiet, Clean, Lit @ LES & Chinatown           Manhattan
# ...                                                  ...                 ...
# 2628         5 Star Luxury 2 BR Suite Heart of Manhattan           Manhattan
# 16204                Cozy bedroom in Brooklyn Sunsetpark            Brooklyn
# 26931                          Lower Park Avenue Pre War           Manhattan
# 29995                    NY Duplex Apartment in Flatiron           Manhattan
# 10692                  Cat-sit in our Awesome Apartment!            Brooklyn
#
# ...

# %%
area = price_reviews1['neighbourhood_group']
price = price_reviews1['price']
fig = plt.figure(figsize = (10, 5))
#creating the bar plot
plt.bar(area, price, color ='maroon', width = 0.4)
plt.xlabel('Area')
plt.ylabel('Price')
plt.title('Price vs Number of reviews')
plt.show()

# %% [markdown]
# From the above Analysis we can say that most people prefer to stay in place where price is less

# %% [markdown]
# 3) Which hosts are the busiest and why?

# %%
busiest_hosts = df.groupby(['host_name', 'neighbourhood_group', 'room_type'])['minimum_nights'].count().reset_index()
busiest_hosts = busiest_hosts.sort_values(by='minimum_nights',ascending = False).head(5)
busiest_hosts
# Out:
#           host_name neighbourhood_group        room_type  minimum_nights
# 16549  Sonder (NYC)           Manhattan  Entire home/apt             319
# 2295     Blueground           Manhattan  Entire home/apt             230
# 12299       Michael           Manhattan  Entire home/apt             143
# 9190           Kara           Manhattan  Entire home/apt             129
# 4128          David           Manhattan  Entire home/apt             117

# %%
name = busiest_hosts['host_name']
stayed = busiest_hosts['minimum_nights']
fig = plt.figure(figsize = (10, 5))
#creating the bar plot
plt.bar(name, stayed, color = 'maroon', width = 0.5)
plt.xlabel('Name of the Host')
plt.ylabel('Minimum number of nights stayed')
plt.title('Busiest Host')
plt.show()

# %% [markdown]
# As we can see Busiest Hosts are
# 1. Sonder(NYC)
# 2. Blueground
# 3. Michael
# 4. Kara
# 5. David
#
# Because these hosts are listing there place in Mahattan which is most popular place according to our previous analysis and the room type Entire home/apt which is preferred by the most number of people

# %% [markdown]
# 4) Is there any noticeable difference of traffic among different areas and what could be the reason for it?

# %%
traffic_areas = df.groupby(['neighbourhood_group', 'room_type'])['minimum_nights'].count().reset_index()
traffic_areas = traffic_areas.sort_values(by='minimum_nights',ascending = False)
traffic_areas
# Out:
#    neighbourhood_group        room_type  minimum_nights
# 6            Manhattan  Entire home/apt           13199
# 4             Brooklyn     Private room           10132
# 3             Brooklyn  Entire home/apt            9559
# 7            Manhattan     Private room            7982
# 10              Queens     Private room            3372
# 9               Queens  Entire home/apt            2096
# 1                Bronx     Private room             652
# 8            Manhattan      Shared room             480
# 5             Brooklyn      Shared room             413
# 0                Bronx  Entire home/apt             379
# 11              Queens      Shared room             198
# 13       Staten Island     Private room             188
# 12       Staten Island  Entire home/apt             176
# 2                Bronx      Shared room              60
# 14       Staten Island      Shared room               9

# %%
room_type = traffic_areas['room_type']
stayed = traffic_areas['minimum_nights']
fig = plt.figure(figsize = (10, 5))
#creating the bar plot
plt.bar(room_type, stayed, color = 'maroon', width = 0.4)
plt.xlabel('Room Type')
plt.ylabel('Minimum number of nights stayed')
plt.title('Traffic Areas')
plt.show()

# %% [markdown]
# From the above Analysis We can say that people are preferring entire home/apt or private room which are present in Mahattan, Brooklyn, Queens and people are preferring listings which are less in price.

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# 1- As we can see most number of listings are from Manhattan created Sondar (NYC), Blueground, Michael, David
#
# 2- From the above Analysis we can say that most people prefer to stay in place where price is less
#
# 3- As we can see Busiest Hosts are
#
# Sonder(NYC)
#
# Blueground
#
# Michael
#
# Kara
#
# David
#
# Because these hosts are listing there place in Mahattan which is most popular place according to our previous analysis and the room type Entire home/apt which is preferred by the most number of people
#
# 4- From the above Analysis We can say that people are preferring entire home/apt or private room which are present in Mahattan, Brooklyn, Queens and people are preferring listings which are less in price.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# I've reached almost the end of the analysis. There might be few analysis which can be done more.
#
# We philosophied about the variables, we analysed 'price' and also checked with the most correlated variables, we dealt with missing data and outliers, we tested some of the fundamental statistical assumptions and we even transformed categorial variables into dummy variables. That's a lot of work that Python helped us make easier.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
